# %%
from __future__ import print_function

import sys

import numpy as np
from pyspark.sql import SparkSession
#查詢最大值最小值
# select 't_coupon_change_log' as tablenm  ,min(id)  as minid,max(id)as maxid, 1 as index  from t_coupon_change_log
# union all
# select 't_coupon_record' as tablenm , min(id) as minid ,max(id) as maxid ,2 as index  from t_coupon_record
# union all
# select 't_coupon_store' as tablenm , min(id) as minid ,max(id) as maxid ,3 as index from t_coupon_store
#############################################################################################################################
# builtins
# __main__
if __name__ == "builtins":
#     tableList=[{"tablenm":'t_coupon_change_log', "lowerbound":'1', "upperbound":'513383', "index":'1' },
#                {"tablenm":'t_coupon_record', "lowerbound":'1', "upperbound":'238418', "index":'2' },
#                {"tablenm":'t_coupon_store', "lowerbound":'1', "upperbound":'238418', "index":'3'}]
    tableList={
        "arkham":{
              "url" : "jdbc:postgresql://credinex-prod-instance-1.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/arkham",
              "user":"master",
              "password":"f5LCyt8EbBQdetC5UHvt",
              "type":"arkham",
              "ls":[
#                   {"tablenm":'t_experience', "lowerbound":'1', "upperbound":'1000000', "index":'1' },
#                   {"tablenm":'t_emergency_contact', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
#                   {"tablenm":'t_file', "lowerbound":'1', "upperbound":'1000000', "index":'3' },
#                   {"tablenm":'t_yituface_verify', "lowerbound":'1', "upperbound":'1000000', "index":'4' },
#                   {"tablenm":'t_order_info', "lowerbound":'1', "upperbound":'1000000', "index":'5' },
#                   {"tablenm":'t_order_flow', "lowerbound":'1', "upperbound":'1000000', "index":'6' },
#                   {"tablenm":'t_card_info', "lowerbound":'1', "upperbound":'1000000', "index":'7' },
#                   {"tablenm":'t_black_mobile', "lowerbound":'1', "upperbound":'1000000', "index":'8' },
#                   {"tablenm":'t_user_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'9' },
#                   {"tablenm":'t_user_profile_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'10' },
#                   {"tablenm":'t_credential_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'11' },
#                   {"tablenm":'t_experience_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'12' },
#                   {"tablenm":'t_emergency_contact_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'13' },
#                   {"tablenm":'t_user_profile', "lowerbound":'1', "upperbound":'1000000', "index":'14' },
#                   {"tablenm":'t_user', "lowerbound":'1', "upperbound":'1000000', "index":'15' },
#                   {"tablenm":'t_region', "lowerbound":'1', "upperbound":'1000000', "index":'16' },
#                   {"tablenm":'t_question_result', "lowerbound":'1', "upperbound":'1000000', "index":'17' },
#                   {"tablenm":'t_risksqs_log', "lowerbound":'1', "upperbound":'1000000', "index":'18' },
#                   {"tablenm":'t_channel_detail', "lowerbound":'1', "upperbound":'1000000', "index":'19' },
#                   {"tablenm":'t_order_device_log', "lowerbound":'1', "upperbound":'1000000', "index":'20' },
#                   {"tablenm":'t_user_install_info', "lowerbound":'1', "upperbound":'1000000', "index":'21' },
#                   {"tablenm":'t_marketing_channel_info', "lowerbound":'1', "upperbound":'1000000', "index":'22' },
#                   {"tablenm":'t_marketing_ref_info', "lowerbound":'1', "upperbound":'1000000', "index":'23' },
#                   {"tablenm":'t_customer_tag_type', "lowerbound":'1', "upperbound":'1000000', "index":'24' },
#                   {"tablenm":'t_login_log', "lowerbound":'1', "upperbound":'1000000', "index":'25' },
#                   {"tablenm":'t_file_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'26' }
                   ],
        },
       "protoss":{
              "url" : "jdbc:postgresql://credinex-prod-instance-1.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/protoss",
              "user":"master",
              "password":"f5LCyt8EbBQdetC5UHvt",
              "type":"protoss",
              "ls":[
#                   {"tablenm":'t_bni_bill', "lowerbound":'1', "upperbound":'1000000', "index":'1' },
#                   {"tablenm":'t_pay_order', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
#                   {"tablenm":'t_request_log', "lowerbound":'1', "upperbound":'1000000', "index":'3' }
              ]
       },
       "credinex_account":{
              "url" : "jdbc:postgresql://credinex-prod-instance-1.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/account",
              "user":"master",
              "password":"f5LCyt8EbBQdetC5UHvt",
              "type": "credinex_account",
              "ls":[
               {"tablenm":'t_credit_balance', "lowerbound":'1', "upperbound":'1000000', "index":'1' },
               {"tablenm":'t_customer_account', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
               {"tablenm":'t_balance_config', "lowerbound":'1', "upperbound":'1000000', "index":'3' },
               {"tablenm":'t_payment_order', "lowerbound":'1', "upperbound":'1000000', "index":'4' },
               {"tablenm":'t_credit_bill', "lowerbound":'1', "upperbound":'1000000', "index":'5' },
               {"tablenm":'t_daily_interest', "lowerbound":'1', "upperbound":'1000000', "index":'6' },
               {"tablenm":'t_ledger_order', "lowerbound":'1', "upperbound":'1000000', "index":'7' },
               {"tablenm":'t_bill_flow', "lowerbound":'1', "upperbound":'1000000', "index":'8' },
               {"tablenm":'t_balance_config', "lowerbound":'1', "upperbound":'1000000', "index":'9' },
               {"tablenm":'t_status_history', "lowerbound":'1', "upperbound":'1000000', "index":'10' },
              {"tablenm":'t_daily_info', "lowerbound":'1', "upperbound":'1000000', "index":'11' },
                   {"tablenm":'t_system_operator_log', "lowerbound":'1', "upperbound":'1000000', "index":'12' },
              ]
       },
       "credinex_repeater":{
              "url" : "jdbc:postgresql://credinex-prod-instance-1.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/repeater",
              "user":"master",
              "password":"f5LCyt8EbBQdetC5UHvt",
              "type": "credinex_repeater",
             "ls":[
#                {"tablenm":'t_rule_result', "lowerbound":'1', "upperbound":'1000000', "index":'1' },
#                {"tablenm":'t_rule_history', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
#                {"tablenm":'t_risk_param', "lowerbound":'1', "upperbound":'1000000', "index":'3' },
#                 {"tablenm":'t_risk_blacklist', "lowerbound":'1', "upperbound":'1000000', "index":'4' }
             ]
        },
        "credinex_hive":{
              "url" : "jdbc:postgresql://credinex-prod-instance-1.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/hive",
              "user":"master",
              "password":"f5LCyt8EbBQdetC5UHvt",
              "type": "credinex_hive",
              "ls":[
#                    {"tablenm":'t_admin_group_rel', "lowerbound":'1', "upperbound":'1000000', "index":'1' },
#                    {"tablenm":'t_order_pool', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
#                    {"tablenm":'t_role', "lowerbound":'1', "upperbound":'1000000', "index":'3' },
#                    {"tablenm":'t_group', "lowerbound":'1', "upperbound":'1000000', "index":'4' },
#                    {"tablenm":'t_code_group', "lowerbound":'1', "upperbound":'1000000', "index":'5' },
#                     {"tablenm":'t_admin', "lowerbound":'1', "upperbound":'1000000', "index":'6' },
                ] 
          }
    }
    spark = SparkSession\
        .builder\
        .appName("Python Demo")\
        .enableHiveSupport()\
        .getOrCreate()
    for database in tableList:
        print(database)
        url = tableList[database]["url"]
        user = tableList[database]["user"]
        password = tableList[database]["password"]
        tbtype = tableList[database]["type"]
        ls = tableList[database]["ls"]
        for row in ls:
            print(row)
            tableNm=row["tablenm"]
            lowerBound=row["lowerbound"]
            upperBound=row["upperbound"]
            df = spark.read.format("jdbc").option("url", url).option("user", user).option("password", password).option("partitionColumn", "id").option("dbtable", tableNm).option("lowerBound", lowerBound).option("upperBound", upperBound).option("numPartitions", 1000).load()
            df.createOrReplaceTempView("t")
            bound = spark.sql("select max(id) max, min(id) min from t")
            max = bound.collect()[0].max
            min = bound.collect()[0].min
            if type(max)==int and type(min)==int and max>min:
                df_table = spark.read.format("jdbc").option("url", url).option("dbtable",  tableNm).option("user", user).option("password", password).option("partitionColumn", "id").option("lowerBound", min).option("upperBound", max).option("numPartitions", 1000).load()
                path="s3://rupiahplus-data-warehouse/aliyun/"+tbtype+"_emr/"+tableNm
                df_table.write.mode("overwrite").orc(path)
#     spark.stop()
# Out:
# VBox()
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>1</td><td>application_1623309155673_0007</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-3-0-39.ap-southeast-1.compute.internal:20888/proxy/application_1623309155673_0007/">Link</a></td><td><a target="_blank" href="http://ip-10-3-0-104.ap-southeast-1.compute.internal:8042/node/containerlogs/container_1623309155673_0007_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# arkham
# protoss
# credinex_account
# {'tablenm': 't_credit_balance', 'lowerbound': '1', 'upperbound': '1000000', 'index': '1'}
# ...

# %%
a=100
type(a)==int
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# True

# %%
# -*- coding: UTF-8 -*-
from __future__ import print_function

import sys

import numpy as np
from pyspark.sql import SparkSession



# t_whitelist_old_customer没Id
#############################################################################################################################
# builtins
# __main__
tableList="#tableListParams#"
if __name__ == "__main__":
    spark = SparkSession\
        .builder\
        .appName("Python Demo")\
        .enableHiveSupport()\
        .getOrCreate()
    tableConf={
         "banda":{
              "url" : "jdbc:postgresql://pgm-d9jkp19xeyji7eat.pgsql.ap-southeast-5.rds.aliyuncs.com:3433/banda",
              "user":"postgres",
              "password":"vHeqPwro2HriV7CrM8Wh",
              "type": "banda",
              "ls":[
                    {"tablenm":"t_admin_audit", "lowerbound":100000, "upperbound":44811409, "index":1}, 
                    {"tablenm":"t_auto_review_loan", "lowerbound":1000000, "upperbound":8409730, "index":2},
                    {"tablenm":"t_bankcard", "lowerbound":100000, "upperbound":7511507, "index":3}, 
                    {"tablenm":"t_channel_details", "lowerbound":122098, "upperbound":9606269, "index":4},
                    {"tablenm":"t_clear_detail_log", "lowerbound":100000, "upperbound":276484, "index":5},
                    {"tablenm":"t_code", "lowerbound":1, "upperbound":84198, "index":6}, 
                    {"tablenm":"t_collection_audit", "lowerbound":100000, "upperbound":24744892, "index":7},
                    {"tablenm":"t_collection_blacklist", "lowerbound":100000, "upperbound":100863, "index":8},
                    {"tablenm":"t_contact", "lowerbound":100000, "upperbound":25118550, "index":9}, 
                    {"tablenm":"t_coupon_send", "lowerbound":100000, "upperbound":102789, "index":10},
                    {"tablenm":"t_customer", "lowerbound":10001, "upperbound":3921768, "index":11}, 
                    {"tablenm":"t_customer_app", "lowerbound":100000, "upperbound":180688, "index":12},
                    {"tablenm":"t_customer_device_info", "lowerbound":100000, "upperbound":2886035, "index":13},
                    {"tablenm":"t_customer_install_info", "lowerbound":100005, "upperbound":4475293, "index":14},
                    {"tablenm":"t_customer_tag_rel", "lowerbound":100000, "upperbound":702593, "index":15}, 
                    {"tablenm":"t_date_range", "lowerbound":1, "upperbound":73201, "index":16}, 
                    {"tablenm":"t_employment", "lowerbound":100000, "upperbound":7512240, "index":17},
                    {"tablenm":"t_engine_rule_detail", "lowerbound":2111776, "upperbound":27013249, "index":18},
                    {"tablenm":"t_file", "lowerbound":100000, "upperbound":37492569, "index":19}, 
                    {"tablenm":"t_invitation", "lowerbound":100000, "upperbound":393540, "index":20},
                    {"tablenm":"t_job_metric", "lowerbound":1, "upperbound":13356044, "index":21},
                    {"tablenm":"t_loan_app", "lowerbound":20001, "upperbound":7571209, "index":22}, 
                    {"tablenm":"t_loan_app_review_summary", "lowerbound":100000, "upperbound":7013427, "index":23},
                    {"tablenm":"t_loan_app_status_log", "lowerbound":100000, "upperbound":40493442, "index":24}, 
                    {"tablenm":"t_loan_issue", "lowerbound":100000, "upperbound":3837427, "index":25}, 
                    {"tablenm":"t_loan_log", "lowerbound":100000, "upperbound":103054, "index":26}, 
                    {"tablenm":"t_loan_tag_rel", "lowerbound":100000, "upperbound":5661696, "index":27},
                    {"tablenm":"t_lpay", "lowerbound":30001, "upperbound":3534002, "index":28}, 
                    {"tablenm":"t_lpay_deposit", "lowerbound":100000, "upperbound":3320845, "index":29},
                    {"tablenm":"t_message", "lowerbound":100000, "upperbound":39574953, "index":30}, 
                    {"tablenm":"t_personal_info", "lowerbound":100000, "upperbound":7512269, "index":31},
                    {"tablenm":"t_record_bankcard", "lowerbound":0, "upperbound":0, "index":32}, 
                    {"tablenm":"t_record_contact", "lowerbound":100000, "upperbound":9054406, "index":33},
                    {"tablenm":"t_record_employment", "lowerbound":100000, "upperbound":2952101, "index":34}, 
                    {"tablenm":"t_record_file", "lowerbound":100000, "upperbound":8370151, "index":35},
                    {"tablenm":"t_record_personal_info", "lowerbound":100000, "upperbound":3156183, "index":36},
                    {"tablenm":"t_review_blacklist", "lowerbound":100000, "upperbound":104163, "index":37}, 
                    {"tablenm":"t_review_step_execution", "lowerbound":100000, "upperbound":13859643, "index":39},
                    {"tablenm":"t_send_coupon_rel", "lowerbound":1, "upperbound":26, "index":40}, 
                    {"tablenm":"t_sms", "lowerbound":1, "upperbound":43548328, "index":41}, 
                    {"tablenm":"t_thirdparty_data", "lowerbound":100003, "upperbound":3575439, "index":42}, 
                    {"tablenm":"t_tongdun_data", "lowerbound":100000, "upperbound":889536, "index":43},
                    {"tablenm":"t_virtual_account", "lowerbound":100000, "upperbound":1868901, "index":44},
                    {"tablenm":"t_login_log", "lowerbound":100000, "upperbound":13016112, "index":45},
                    {"tablenm":"t_group", "lowerbound":100000, "upperbound":100133, "index":46},
                    {"tablenm":"t_admin", "lowerbound":70, "upperbound":101514, "index":47},
                    {"tablenm":"t_admin_group_rel", "lowerbound":100000, "upperbound":100991, "index":48},
                    {"tablenm":"t_af_bill", "lowerbound":100309, "upperbound":100531, "index":49},
                    {"tablenm":"t_ai_rudder_schedule_mobile", "lowerbound":100000, "upperbound":1171587, "index":50},
                    {"tablenm":"t_test_customer", "lowerbound":100000, "upperbound":1171587, "index":51},
                    {"tablenm":"t_amount_reduce_record", "lowerbound":1, "upperbound":1000, "index":52},
                    {"tablenm":"t_mobile_tag_rel", "lowerbound":100000, "upperbound":1171587, "index":53},
                    {"tablenm":"t_bankcard_verify", "lowerbound":100000, "upperbound":1171587, "index":54},
                    {"tablenm":"t_bankcard_merchant", "lowerbound":100000, "upperbound":1171587, "index":55},
                    {"tablenm":"t_hit_blacklist_record", "lowerbound":100000, "upperbound":1171587, "index":56},
                    {"tablenm":"t_case_distribution_log", "lowerbound":100000, "upperbound":1171587, "index":57},
                    {"tablenm":"t_coupon_request", "lowerbound":100000, "upperbound":1171587, "index":58},
                    {"tablenm":"t_reduce", "lowerbound":100000, "upperbound":276484, "index":59},
                    {"tablenm":"t_admin_group", "lowerbound":100000, "upperbound":276484, "index":60},
                    {"tablenm":"t_department_group", "lowerbound":100000, "upperbound":276484, "index":61}
              ]
        },
        "arkham":{
              "url" : "jdbc:postgresql://credinex-prod-instance-1.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/arkham",
              "user":"master",
              "password":"f5LCyt8EbBQdetC5UHvt",
              "type":"arkham",
              "ls":[
                  {"tablenm":'t_experience', "lowerbound":'1', "upperbound":'1000000', "index":'1' },
                  {"tablenm":'t_emergency_contact', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
                  {"tablenm":'t_file', "lowerbound":'1', "upperbound":'1000000', "index":'3' },
                  {"tablenm":'t_yituface_verify', "lowerbound":'1', "upperbound":'1000000', "index":'4' },
                  {"tablenm":'t_order_info', "lowerbound":'1', "upperbound":'1000000', "index":'5' },
                  {"tablenm":'t_order_flow', "lowerbound":'1', "upperbound":'1000000', "index":'6' },
                  {"tablenm":'t_card_info', "lowerbound":'1', "upperbound":'1000000', "index":'7' },
                  {"tablenm":'t_black_mobile', "lowerbound":'1', "upperbound":'1000000', "index":'8' },
                  {"tablenm":'t_user_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'9' },
                  {"tablenm":'t_user_profile_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'10' },
                  {"tablenm":'t_credential_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'11' },
                  {"tablenm":'t_experience_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'12' },
                  {"tablenm":'t_emergency_contact_snapshot', "lowerbound":'1', "upperbound":'1000000', "index":'13' },
                  {"tablenm":'t_user_profile', "lowerbound":'1', "upperbound":'1000000', "index":'14' },
                  {"tablenm":'t_user', "lowerbound":'1', "upperbound":'1000000', "index":'15' },
                  {"tablenm":'t_region', "lowerbound":'1', "upperbound":'1000000', "index":'16' },
                  {"tablenm":'t_question_result', "lowerbound":'1', "upperbound":'1000000', "index":'20' },
                  {"tablenm":'t_risksqs_log', "lowerbound":'1', "upperbound":'1000000', "index":'21' },
                  {"tablenm":'t_channel_detail', "lowerbound":'1', "upperbound":'1000000', "index":'22' },
                  {"tablenm":'t_order_device_log', "lowerbound":'1', "upperbound":'1000000', "index":'23' },
                  {"tablenm":'t_user_install_info', "lowerbound":'1', "upperbound":'1000000', "index":'24' },
                  {"tablenm":'t_marketing_channel_info', "lowerbound":'1', "upperbound":'1000000', "index":'25' },
                  {"tablenm":'t_marketing_ref_info', "lowerbound":'1', "upperbound":'1000000', "index":'26' },
                  {"tablenm":'t_customer_tag_type', "lowerbound":'1', "upperbound":'1000000', "index":'27' },
            ],
        },
       "protoss":{
              "url" : "jdbc:postgresql://credinex-prod-instance-1.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/protoss",
              "user":"master",
              "password":"f5LCyt8EbBQdetC5UHvt",
              "type":"protoss",
              "ls":[
                  {"tablenm":'t_bni_bill', "lowerbound":'1', "upperbound":'1000000', "index":'1' },
                  {"tablenm":'t_pay_order', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
                  {"tablenm":'t_request_log', "lowerbound":'1', "upperbound":'1000000', "index":'3' }
              ]
       },
       "credinex_account":{
              "url" : "jdbc:postgresql://credinex-prod-instance-1.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/account",
              "user":"master",
              "password":"f5LCyt8EbBQdetC5UHvt",
              "type": "credinex_account",
              "ls":[
               {"tablenm":'t_credit_balance', "lowerbound":'1', "upperbound":'1000000', "index":'1' },
               {"tablenm":'t_customer_account', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
               {"tablenm":'t_balance_config', "lowerbound":'1', "upperbound":'1000000', "index":'3' },
               {"tablenm":'t_payment_order', "lowerbound":'1', "upperbound":'1000000', "index":'4' },
               {"tablenm":'t_credit_bill', "lowerbound":'1', "upperbound":'1000000', "index":'5' },
               {"tablenm":'t_daily_interest', "lowerbound":'1', "upperbound":'1000000', "index":'6' },
               {"tablenm":'t_ledger_order', "lowerbound":'1', "upperbound":'1000000', "index":'7' },
               {"tablenm":'t_bill_flow', "lowerbound":'1', "upperbound":'1000000', "index":'8' },
               {"tablenm":'t_balance_config', "lowerbound":'1', "upperbound":'1000000', "index":'9' },
               {"tablenm":'t_status_history', "lowerbound":'1', "upperbound":'1000000', "index":'10' },
               {"tablenm":'t_daily_info', "lowerbound":'1', "upperbound":'1000000', "index":'11' },
               {"tablenm":'t_system_operator_log', "lowerbound":'1', "upperbound":'1000000', "index":'12' },
              ]
       },
       "credinex_repeater":{
              "url" : "jdbc:postgresql://credinex-prod-instance-1.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/repeater",
              "user":"master",
              "password":"f5LCyt8EbBQdetC5UHvt",
              "type": "credinex_repeater",
             "ls":[
               {"tablenm":'t_rule_result', "lowerbound":'1', "upperbound":'1000000', "index":'1' },
               {"tablenm":'t_rule_history', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
               {"tablenm":'t_risk_param', "lowerbound":'1', "upperbound":'1000000', "index":'3' },
               {"tablenm":'t_risk_blacklist', "lowerbound":'1', "upperbound":'1000000', "index":'4' }
             ]
        },
        "credinex_hive":{
              "url" : "jdbc:postgresql://credinex-prod-instance-1.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/hive",
              "user":"master",
              "password":"f5LCyt8EbBQdetC5UHvt",
              "type": "credinex_hive",
              "ls":[
                   {"tablenm":'t_admin_group_rel', "lowerbound":'1', "upperbound":'1000000', "index":'1' },
                   {"tablenm":'t_order_pool', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
                   {"tablenm":'t_role', "lowerbound":'1', "upperbound":'1000000', "index":'3' },
                   {"tablenm":'t_group', "lowerbound":'1', "upperbound":'1000000', "index":'4' },
                   {"tablenm":'t_code_group', "lowerbound":'1', "upperbound":'1000000', "index":'5' },
                   {"tablenm":'t_admin', "lowerbound":'1', "upperbound":'1000000', "index":'6' },
                ] 
          },
        "lovina":{
              "url" : "jdbc:postgresql://lovina-prod.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/lovina",
              "user":"lovina",
              "password":"UFXXExqnXJix9b2eM9Ge",
              "type": "lovina",
              "ls":[
                   {"tablenm":'t_charging', "lowerbound":'1', "upperbound":'10000', "index":'1' },
                   {"tablenm":'t_ktp', "lowerbound":'1', "upperbound":'10000', "index":'2' },
                   {"tablenm":'t_jne_express', "lowerbound":'1', "upperbound":'10000', "index":'3' }       
                ] 
          },
        "notification":{
              "url" : "jdbc:postgresql://adapundi-services-cluster.cluster-ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/notification",
              "user":"etl_sync",
              "password":"3CN04h092qfU2FfUKzft",
              "type":"notification",
              "ls":[
                  {"tablenm":'t_message', "lowerbound":'1', "upperbound":'11188826', "index":'1' },
                  {"tablenm":'t_message_channel', "lowerbound":'1', "upperbound":'467', "index":'2' },
                  {"tablenm":'t_message_template', "lowerbound":'1', "upperbound":'467', "index":'3' },
                  {"tablenm":'t_product_department', "lowerbound":'1', "upperbound":'3', "index":'4' },
                  {"tablenm":'t_template', "lowerbound":'1', "upperbound":'500', "index":'5' },
                  {"tablenm":'t_trigger', "lowerbound":'1', "upperbound":'265', "index":'6' },
            ],
        },
        "coupon":{
              "url" : "jdbc:postgresql://lovina-prod.ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/coupon",
              "user": "elt_sync",
              "password":"VW7buZwvYWhVMusrkZN1",
              "type": "coupon",
              "ls":[
                   {"tablenm":'t_coupon_change_log', "lowerbound":'1', "upperbound":'513383', "index":'1' },
                   {"tablenm":'t_coupon_record', "lowerbound":'1', "upperbound":'238418', "index":'2' },
                   {"tablenm":'t_coupon_store', "lowerbound":'1', "upperbound":'238418', "index":'3'}
                ] 
          },
         "telemarket":{
              "url" : "jdbc:postgresql://adapundi-services-cluster.cluster-ct3lmpqmpvcq.ap-southeast-1.rds.amazonaws.com:5432/telemarket",
              "user":"etl_sync",
              "password":"3CN04h092qfU2FfUKzft",
              "type":"telemarket",
              "ls":[
                  {"tablenm":'t_admin_group_rel', "lowerbound":'1', "upperbound":'1000000', "index":'1'},
                  {"tablenm":'t_callcenter_call_journaling', "lowerbound":'1', "upperbound":'1000000', "index":'2' },
                  {"tablenm":'t_task_pool', "lowerbound":'1', "upperbound":'1000000', "index":'3' },
                  {"tablenm":'t_task_pool_tag_rel', "lowerbound":'1', "upperbound":'1000000', "index":'4' },
                  {"tablenm":'t_case_status_log', "lowerbound":'1', "upperbound":'1000000', "index":'5' },
                  {"tablenm":'t_tag', "lowerbound":'1', "upperbound":'1000000', "index":'6' },
                  {"tablenm":'t_group', "lowerbound":'1', "upperbound":'1000000', "index":'7' },
                  {"tablenm":'t_code_group', "lowerbound":'1', "upperbound":'1000000', "index":'8' },
              ]
        }
    }
    for dbtype in tableList.keys():
        print(dbtype ,tableList[dbtype])
        if tableConf.get(dbtype):
            ls=[]
            for table in tableList[dbtype]:
                url = tableConf[dbtype]["url"]
                user = tableConf[dbtype]["user"]
                password = tableConf[dbtype]["password"]
                tbtype = tableConf[dbtype]["type"]
                if table=='*':
                    ls = tableConf[dbtype]["ls"]
#                     全部的
                else:
                    ls=ls+[tb for tb in tableConf[dbtype]["ls"] if tb["tablenm"]==table]
            for row in ls:
                tableNm=row["tablenm"]
                lowerBound=row["lowerbound"]
                upperBound=row["upperbound"]
                df = spark.read.format("jdbc").option("url", url).option("user", user).option("password", password).option("partitionColumn", "id").option("dbtable", tableNm).option("lowerBound", lowerBound).option("upperBound", upperBound).option("numPartitions", 1000).load()
                df.createOrReplaceTempView("t")
                bound = spark.sql("select max(id) max, min(id) min from t")
                max = bound.collect()[0].max
                min = bound.collect()[0].min
                if type(max)==int and type(min)==int and max>min:
                    df_table = spark.read.format("jdbc").option("url", url).option("dbtable",  tableNm).option("user", user).option("password", password).option("partitionColumn", "id").option("lowerBound", min).option("upperBound", max).option("numPartitions", 1000).load()
                    path="s3://rupiahplus-data-warehouse/aliyun/"+tbtype+"_emr/"+tableNm
                    df_table.write.mode("overwrite").orc(path)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error occurred while calling o141.load.
# : org.postgresql.util.PSQLException: The connection attempt failed.
# 	at org.postgresql.core.v3.ConnectionFactoryImpl.openConnectionImpl(ConnectionFactoryImpl.java:292)
# 	at org.postgresql.core.ConnectionFactory.openConnection(ConnectionFactory.java:49)
# 	at org.postgresql.jdbc.PgConnection.<init>(PgConnection.java:211)
# 	at org.postgresql.Driver.makeConnection(Driver.java:458)
# 	at org.postgresql.Driver.connect(Driver.java:260)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JdbcUtils$$anonfun$createConnectionFactory$1.apply(JdbcUtils.scala:63)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JdbcUtils$$anonfun$createConnectionFactory$1.apply(JdbcUtils.scala:54)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JDBCRDD$.resolveTable(JDBCRDD.scala:56)
# ...
